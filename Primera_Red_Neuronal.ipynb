# %%
#Uso de Tensorflow / PyThorch

# %%
import pandas as pxndx
Datos = pxndx.read_csv("celcius.csv")

# %%
Datos.head()
# Out:
#    Celsius  fahrenheit
# 0      -40       -40.0
# 1      -10        14.0
# 2        0        32.0
# 3        8        46.4
# 4       15        59.0

# %%
X = Datos["Celsius"].values
Y= Datos["fahrenheit"].values

# %%
import tensorflow as Tf
Modelo = Tf.keras.Sequential([
    Tf.keras.layers.Input(shape=(1,)), #La entrada, los celsius: 1 solo dato
    Tf.keras.layers.Dense(units=1), #La salida. Tambien es un dato: los grados fahrenheit
])
Modelo.compile(
    optimizer= Tf.keras.optimizers.Adam(.1),
    loss="mean_squared_error"
)
# Out:
# c:\Users\MAPCO1720\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
entrenamiento = Modelo.fit(X,Y,epochs=1000) #epechos son las vueltas que le costara
                                            #hasta aprender
# Out:
# Epoch 1/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - loss: 8588.2344
# Epoch 2/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 8171.7383
# Epoch 3/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 7766.9663
# Epoch 4/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 7374.1069
# Epoch 5/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 6993.3413
# Epoch 6/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 6624.8193
# Epoch 7/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 6268.6797
# Epoch 8/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 5925.0356
# Epoch 9/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 5593.9775
# Epoch 10/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 5275.5728
# Epoch 11/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 4969.8604
# Epoch 12/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 4676.8574
# Epoch 13/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 4396.5522
# Epoch 14/1000
# ...

# %%
import matplotlib.pyplot as plt
plt.xlabel("# Epoca")
plt.ylabel("Magnitud de la pérdida")
plt.plot(entrenamiento.history["loss"])

# %%
import tensorflow as tf

c = tf.constant([[1230.0]], dtype=tf.float32)
prediccion = Modelo.predict(c)
print(f"Prediccion: 123 Celsius son {prediccion[0][0]} Fahrenheit")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Prediccion: 123 Celsius son 2246.572265625 Fahrenheit
